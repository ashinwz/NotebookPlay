# %%
import rdkit
import logging
from rdkit import Chem
from rdkit import RDLogger
from rdkit.Chem import AllChem
import molvs
from molvs import standardize_smiles
from molvs import validate_smiles, Validator

smiles = "Cc1ccnc1C"

# %%
mol = Chem.MolFromSmiles(smiles, sanitize=False)
# try:
#     Chem.SanitizeMol(mol)
# except ValueError:
#     None
mol

# %%
mol_trans_smiles = Chem.MolToSmiles(mol, kekuleSmiles=True)
mol_trans_smiles
# Out:
# ---------------------------------------------------------------------------
# KekulizeException                         Traceback (most recent call last)
# Input In [16], in <cell line: 1>()
# ----> 1 mol_trans_smiles = Chem.MolToSmiles(mol, kekuleSmiles=True)
#       2 mol_trans_smiles
#
# KekulizeException: Can't kekulize mol.  Unkekulized atoms: 1 2 3 4 5

# %%
Chem.MolFromSmiles(mol_trans_smiles)
